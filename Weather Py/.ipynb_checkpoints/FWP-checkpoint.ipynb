# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from citipy import citipy
api_key = "2d7bc754b1f208baf1d97b9f731cceb6"

# %%
cl = pd.read_csv("C:/Users/write/Ur_APIHW/Weather Py/CityList.csv")
#drop na values
cl.dropna(inplace = True)
cl
# Out:
#           ID           City Name  Latitude  Longitude        Country
# 0    4724892        Saint Hedwig  29.41440  -98.20001  United States
# 1    4724966            Saint Jo  33.69483  -97.52252  United States
# 2    4725484          Saint Paul  33.04123  -96.55027  United States
# 3    4725486          Saint Paul  28.09946  -97.55583  United States
# 4    4725807              Salado  30.94713  -97.53862  United States
# ..       ...                 ...       ...        ...            ...
# 525  4778945        Pimmit Hills  38.91289  -77.20081  United States
# 526  4779923            Poquoson  37.12237  -76.34578  United States
# 527  4779999          Portsmouth  36.83543  -76.29827  United States
# 528  4780011  Portsmouth Heights  36.82098  -76.36883  United States
# 529  4780087       Potomac Mills  38.64595  -77.29415  United States
#
# [530 rows x 5 columns]

# %%
lat_range = (-90, 90)
lng_range = (-180, 180)

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %%
len(cl)
# Out:
# 530

# %%
#test for api
url = "http://api.openweathermap.org/data/2.5/weather?"

units = "imperial"

city = cl["City Name"][0]

query_url = f"{url}appid={api_key}&units={units}&q={city}"

weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'coord': {'lon': -98.2, 'lat': 29.4144}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 35.33, 'feels_like': 27.81, 'temp_min': 33.8, 'temp_max': 37, 'pressure': 1030, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 330}, 'clouds': {'all': 1}, 'dt': 1610427409, 'sys': {'type': 1, 'id': 5685, 'country': 'US', 'sunrise': 1610371703, 'sunset': 1610409175}, 'timezone': -21600, 'id': 4724892, 'name': 'Saint Hedwig', 'cod': 200}.

# %%
params = {"key": api_key}

url = "http://api.openweathermap.org/data/2.5/weather?"

units = "imperial"

##http://api.openweathermap.org/data/2.5/weather?appid=2d7bc754b1f208baf1d97b9f731cceb6&units=imperial&q=ushuaia

# %%
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("Does not exist")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Search Complete  ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | paita
# Does not exist
# Processing Record 2 of Set 1 | qaanaaq
# Does not exist
# Processing Record 3 of Set 1 | odweyne
# Does not exist
# Processing Record 4 of Set 1 | samarai
# Does not exist
# Processing Record 5 of Set 1 | hilo
# Does not exist
# Processing Record 6 of Set 1 | ballina
# Does not exist
# Processing Record 7 of Set 1 | georgetown
# Does not exist
# Processing Record 8 of Set 1 | ibra
# Does not exist
# Processing Record 9 of Set 1 | illoqqortoormiut
# Does not exist
# Processing Record 10 of Set 1 | pevek
# Does not exist
# Processing Record 11 of Set 1 | ponta do sol
# Does not exist
# Processing Record 12 of Set 1 | rikitea
# Does not exist
# Processing Record 13 of Set 1 | codrington
# Does not exist
# Processing Record 14 of Set 1 | george
# Does not exist
# Processing Record 15 of Set 1 | hermanus
# Does not exist
# Processing Record 16 of Set 1 | hasaki
# Does not exist
# Processing Record 17 of Set 1 | kapaa
# Does not exist
# Processing Record 18 of Set 1 | nizhneyansk
# Does not exist
# Processing Record 19 of Set 1 | alyangula
# Does not exist
# Processing Record 20 of Set 1 | torbay
# Does not exist
# Processing Record 21 of Set 1 | atuona
# Does not exist
# Processing Record 22 of Set 1 | saint-philippe
# Does not exist
# Processing Record 23 of Set 1 | moba
# Does not exist
# Processing Record 24 of Set 1 | punta arenas
# Does not exist
# Processing Record 25 of Set 1 | paamiut
# Does not exist
# Processing Record 26 of Set 1 | east london
# Does not exist
# Processing Record 27 of Set 1 | barentsburg
# Does not exist
# Processing Record 28 of Set 1 | mar del plata
# Does not exist
# Processing Record 29 of Set 1 | ushuaia
# Does not exist
# Processing Record 30 of Set 1 | bredasdorp
# Does not exist
# Processing Record 31 of Set 1 | ukiah
# Does not exist
# Processing Record 32 of Set 1 | sorong
# Does not exist
# Processing Record 33 of Set 1 | vaini
# Does not exist
# Processing Record 34 of Set 1 | trapani
# Does not exist
# Processing Record 35 of Set 1 | kupang
# Does not exist
# Processing Record 36 of Set 1 | praia
# Does not exist
# Processing Record 37 of Set 1 | butaritari
# Does not exist
# Processing Record 38 of Set 1 | albany
# Does not exist
# Processing Record 39 of Set 1 | jamestown
# Does not exist
# Processing Record 40 of Set 1 | meulaboh
# Does not exist
# Processing Record 41 of Set 1 | madingou
# Does not exist
# Processing Record 42 of Set 1 | karamay
# Does not exist
# Processing Record 43 of Set 1 | tolaga bay
# Does not exist
# Processing Record 44 of Set 1 | cape town
# Does not exist
# Processing Record 45 of Set 1 | hithadhoo
# Does not exist
# Processing Record 46 of Set 1 | shumikha
# Does not exist
# Processing Record 47 of Set 1 | taruma
# Does not exist
# Processing Record 48 of Set 1 | nanortalik
# Does not exist
# Processing Record 49 of Set 1 | esperance
# Does not exist
# Processing Record 50 of Set 1 | yeppoon
# Does not exist
# Processing Record 0 of Set 2 | mataura
# Does not exist
# Processing Record 1 of Set 2 | gaoua
# Does not exist
# Processing Record 2 of Set 2 | port elizabeth
# Does not exist
# Processing Record 3 of Set 2 | bengkulu
# Does not exist
# Processing Record 4 of Set 2 | marawi
# Does not exist
# Processing Record 5 of Set 2 | shimoda
# Does not exist
# Processing Record 6 of Set 2 | puerto ayora
# Does not exist
# Processing Record 7 of Set 2 | ossora
# Does not exist
# Processing Record 8 of Set 2 | hobyo
# Does not exist
# Processing Record 9 of Set 2 | new norfolk
# Does not exist
# Processing Record 10 of Set 2 | ribeira grande
# Does not exist
# Processing Record 11 of Set 2 | lebu
# Does not exist
# Processing Record 12 of Set 2 | san patricio
# Does not exist
# Processing Record 13 of Set 2 | yellowknife
# Does not exist
# Processing Record 14 of Set 2 | bethel
# Does not exist
# Processing Record 15 of Set 2 | salalah
# Does not exist
# Processing Record 16 of Set 2 | dikson
# Does not exist
# Processing Record 17 of Set 2 | pimentel
# Does not exist
# Processing Record 18 of Set 2 | hearst
# Does not exist
# Processing Record 19 of Set 2 | vao
# Does not exist
# Processing Record 20 of Set 2 | tias
# Does not exist
# Processing Record 21 of Set 2 | akyab
# Does not exist
# Processing Record 22 of Set 2 | faanui
# Does not exist
# Processing Record 23 of Set 2 | hami
# Does not exist
# Processing Record 24 of Set 2 | la asuncion
# Does not exist
# Processing Record 25 of Set 2 | airai
# Does not exist
# Processing Record 26 of Set 2 | busselton
# Does not exist
# Processing Record 27 of Set 2 | nizhniy kuranakh
# Does not exist
# Processing Record 28 of Set 2 | tasiilaq
# Does not exist
# Processing Record 29 of Set 2 | loukhi
# Does not exist
# Processing Record 30 of Set 2 | mbini
# Does not exist
# Processing Record 31 of Set 2 | barrow
# Does not exist
# Processing Record 32 of Set 2 | mount gambier
# Does not exist
# Processing Record 33 of Set 2 | cherskiy
# Does not exist
# Processing Record 34 of Set 2 | hobart
# Does not exist
# Processing Record 35 of Set 2 | isangel
# Does not exist
# Processing Record 36 of Set 2 | poso
# Does not exist
# Processing Record 37 of Set 2 | wiarton
# Does not exist
# Processing Record 38 of Set 2 | katsuura
# Does not exist
# Processing Record 39 of Set 2 | kajansi
# Does not exist
# Processing Record 40 of Set 2 | meyungs
# Does not exist
# Processing Record 41 of Set 2 | kruisfontein
# Does not exist
# Processing Record 42 of Set 2 | harwich
# Does not exist
# Processing Record 43 of Set 2 | namatanai
# Does not exist
# Processing Record 44 of Set 2 | beringovskiy
# Does not exist
# Processing Record 45 of Set 2 | krasnoselkup
# Does not exist
# Processing Record 46 of Set 2 | oistins
# Does not exist
# Processing Record 47 of Set 2 | sao felix do xingu
# Does not exist
# Processing Record 48 of Set 2 | buala
# Does not exist
# Processing Record 49 of Set 2 | port alfred
# Does not exist
# Processing Record 0 of Set 3 | grand river south east
# Does not exist
# Processing Record 1 of Set 3 | bluff
# Does not exist
# Processing Record 2 of Set 3 | vanimo
# Does not exist
# Processing Record 3 of Set 3 | urucara
# Does not exist
# Processing Record 4 of Set 3 | komsomolskiy
# Does not exist
# Processing Record 5 of Set 3 | ovalle
# Does not exist
# Processing Record 6 of Set 3 | sao filipe
# Does not exist
# Processing Record 7 of Set 3 | saleaula
# Does not exist
# Processing Record 8 of Set 3 | castro
# Does not exist
# Processing Record 9 of Set 3 | sergeyevka
# Does not exist
# Processing Record 10 of Set 3 | upernavik
# Does not exist
# Processing Record 11 of Set 3 | kyzyl-suu
# Does not exist
# Processing Record 12 of Set 3 | marcona
# Does not exist
# Processing Record 13 of Set 3 | khatanga
# Does not exist
# Processing Record 14 of Set 3 | killybegs
# Does not exist
# Processing Record 15 of Set 3 | manzanillo
# Does not exist
# Processing Record 16 of Set 3 | niquero
# Does not exist
# Processing Record 17 of Set 3 | mana
# Does not exist
# Processing Record 18 of Set 3 | bogorodskoye
# Does not exist
# Processing Record 19 of Set 3 | barahona
# Does not exist
# Processing Record 20 of Set 3 | uyuni
# Does not exist
# Processing Record 21 of Set 3 | luderitz
# Does not exist
# Processing Record 22 of Set 3 | nikolskoye
# Does not exist
# Processing Record 23 of Set 3 | fort nelson
# Does not exist
# Processing Record 24 of Set 3 | kohtla-jarve
# Does not exist
# Processing Record 25 of Set 3 | sorland
# Does not exist
# Processing Record 26 of Set 3 | laguna de perlas
# Does not exist
# Processing Record 27 of Set 3 | aswan
# Does not exist
# Processing Record 28 of Set 3 | strandby
# Does not exist
# Processing Record 29 of Set 3 | kahului
# Does not exist
# Processing Record 30 of Set 3 | tabuk
# Does not exist
# Processing Record 31 of Set 3 | avarua
# Does not exist
# Processing Record 32 of Set 3 | kristiinankaupunki
# Does not exist
# Processing Record 33 of Set 3 | uk
# Does not exist
# Processing Record 34 of Set 3 | necochea
# Does not exist
# Processing Record 35 of Set 3 | peski
# Does not exist
# Processing Record 36 of Set 3 | vila franca do campo
# Does not exist
# Processing Record 37 of Set 3 | nuuk
# Does not exist
# Processing Record 38 of Set 3 | jumla
# Does not exist
# Processing Record 39 of Set 3 | dalby
# Does not exist
# Processing Record 40 of Set 3 | carnarvon
# Does not exist
# Processing Record 41 of Set 3 | bela crkva
# Does not exist
# Processing Record 42 of Set 3 | ninghai
# Does not exist
# Processing Record 43 of Set 3 | ishim
# Does not exist
# Processing Record 44 of Set 3 | fairbanks
# Does not exist
# Processing Record 45 of Set 3 | tual
# Does not exist
# Processing Record 46 of Set 3 | malanje
# Does not exist
# Processing Record 47 of Set 3 | guanica
# Does not exist
# Processing Record 48 of Set 3 | mikasa
# Does not exist
# Processing Record 49 of Set 3 | akhisar
# Does not exist
# Processing Record 0 of Set 4 | ilulissat
# Does not exist
# Processing Record 1 of Set 4 | roald
# Does not exist
# Processing Record 2 of Set 4 | port macquarie
# Does not exist
# Processing Record 3 of Set 4 | ucluelet
# Does not exist
# Processing Record 4 of Set 4 | santa marta
# Does not exist
# Processing Record 5 of Set 4 | wajima
# Does not exist
# Processing Record 6 of Set 4 | santa cruz
# Does not exist
# Processing Record 7 of Set 4 | vila velha
# Does not exist
# Processing Record 8 of Set 4 | mecca
# Does not exist
# Processing Record 9 of Set 4 | koutsouras
# Does not exist
# Processing Record 10 of Set 4 | tiksi
# Does not exist
# Processing Record 11 of Set 4 | lasa
# Does not exist
# Processing Record 12 of Set 4 | irbil
# Does not exist
# Processing Record 13 of Set 4 | alice springs
# Does not exist
# Processing Record 14 of Set 4 | baruun-urt
# Does not exist
# Processing Record 15 of Set 4 | mandalgovi
# Does not exist
# Processing Record 16 of Set 4 | mizdah
# Does not exist
# Processing Record 17 of Set 4 | ous
# Does not exist
# Processing Record 18 of Set 4 | luang prabang
# Does not exist
# Processing Record 19 of Set 4 | balkanabat
# Does not exist
# Processing Record 20 of Set 4 | kavieng
# Does not exist
# Processing Record 21 of Set 4 | tahe
# Does not exist
# Processing Record 22 of Set 4 | bambous virieux
# Does not exist
# Processing Record 23 of Set 4 | svetlyy
# Does not exist
# Processing Record 24 of Set 4 | alekseyevsk
# Does not exist
# Processing Record 25 of Set 4 | haines junction
# Does not exist
# Processing Record 26 of Set 4 | invermere
# Does not exist
# Processing Record 27 of Set 4 | zhigansk
# Does not exist
# Processing Record 28 of Set 4 | stromness
# Does not exist
# Processing Record 29 of Set 4 | lakatoro
# Does not exist
# Processing Record 30 of Set 4 | grindavik
# Does not exist
# Processing Record 31 of Set 4 | taolanaro
# Does not exist
# Processing Record 32 of Set 4 | provideniya
# Does not exist
# Processing Record 33 of Set 4 | hualmay
# Does not exist
# Processing Record 34 of Set 4 | mareeba
# Does not exist
# Processing Record 35 of Set 4 | maryborough
# Does not exist
# Processing Record 36 of Set 4 | strezhevoy
# Does not exist
# Processing Record 37 of Set 4 | kaitangata
# Does not exist
# Processing Record 38 of Set 4 | chokurdakh
# Does not exist
# Processing Record 39 of Set 4 | thompson
# Does not exist
# Processing Record 40 of Set 4 | clarence town
# Does not exist
# Processing Record 41 of Set 4 | port lincoln
# Does not exist
# Processing Record 42 of Set 4 | erdemli
# Does not exist
# Processing Record 43 of Set 4 | tumannyy
# Does not exist
# Processing Record 44 of Set 4 | chute-aux-outardes
# Does not exist
# Processing Record 45 of Set 4 | arraial do cabo
# Does not exist
# Processing Record 46 of Set 4 | katherine
# Does not exist
# Processing Record 47 of Set 4 | tupik
# Does not exist
# Processing Record 48 of Set 4 | sai buri
# Does not exist
# Processing Record 49 of Set 4 | kaffrine
# Does not exist
# Processing Record 0 of Set 5 | amderma
# Does not exist
# Processing Record 1 of Set 5 | bossangoa
# Does not exist
# Processing Record 2 of Set 5 | lorengau
# Does not exist
# Processing Record 3 of Set 5 | coihaique
# Does not exist
# Processing Record 4 of Set 5 | sfantu gheorghe
# Does not exist
# Processing Record 5 of Set 5 | aklavik
# Does not exist
# Processing Record 6 of Set 5 | omsukchan
# Does not exist
# Processing Record 7 of Set 5 | coalville
# Does not exist
# Processing Record 8 of Set 5 | bintulu
# Does not exist
# Processing Record 9 of Set 5 | vlasenica
# Does not exist
# Processing Record 10 of Set 5 | kidal
# Does not exist
# Processing Record 11 of Set 5 | leningradskiy
# Does not exist
# Processing Record 12 of Set 5 | kodiak
# Does not exist
# Processing Record 13 of Set 5 | mayo
# Does not exist
# Processing Record 14 of Set 5 | ancud
# Does not exist
# Processing Record 15 of Set 5 | saint anthony
# Does not exist
# Processing Record 16 of Set 5 | ocos
# Does not exist
# Processing Record 17 of Set 5 | kulhudhuffushi
# Does not exist
# Processing Record 18 of Set 5 | nouadhibou
# Does not exist
# Processing Record 19 of Set 5 | praya
# Does not exist
# Processing Record 20 of Set 5 | dingle
# Does not exist
# Processing Record 21 of Set 5 | viligili
# Does not exist
# Processing Record 22 of Set 5 | cayenne
# Does not exist
# Processing Record 23 of Set 5 | anadyr
# Does not exist
# Processing Record 24 of Set 5 | flin flon
# Does not exist
# Processing Record 25 of Set 5 | mys shmidta
# Does not exist
# Processing Record 26 of Set 5 | manta
# Does not exist
# Processing Record 27 of Set 5 | upata
# Does not exist
# Processing Record 28 of Set 5 | sosva
# Does not exist
# Processing Record 29 of Set 5 | kropotkin
# Does not exist
# Processing Record 30 of Set 5 | bodden town
# Does not exist
# Processing Record 31 of Set 5 | aksay
# Does not exist
# Processing Record 32 of Set 5 | deputatskiy
# Does not exist
# Processing Record 33 of Set 5 | victoria
# Does not exist
# Processing Record 34 of Set 5 | saldanha
# Does not exist
# Processing Record 35 of Set 5 | tuy hoa
# Does not exist
# Processing Record 36 of Set 5 | serra
# Does not exist
# Processing Record 37 of Set 5 | nemuro
# Does not exist
# Processing Record 38 of Set 5 | evensk
# Does not exist
# Processing Record 39 of Set 5 | itarema
# Does not exist
# Processing Record 40 of Set 5 | attawapiskat
# Does not exist
# Processing Record 41 of Set 5 | berlevag
# Does not exist
# Processing Record 42 of Set 5 | souillac
# Does not exist
# Processing Record 43 of Set 5 | rocha
# Does not exist
# Processing Record 44 of Set 5 | chuy
# Does not exist
# Processing Record 45 of Set 5 | tobetsu
# Does not exist
# Processing Record 46 of Set 5 | fortuna
# Does not exist
# Processing Record 47 of Set 5 | kandrian
# Does not exist
# Processing Record 48 of Set 5 | baykit
# Does not exist
# Processing Record 49 of Set 5 | rundu
# Does not exist
# Processing Record 0 of Set 6 | santa maria
# Does not exist
# Processing Record 1 of Set 6 | eirunepe
# Does not exist
# Processing Record 2 of Set 6 | waipawa
# Does not exist
# Processing Record 3 of Set 6 | mahebourg
# Does not exist
# Processing Record 4 of Set 6 | verkh-usugli
# Does not exist
# Processing Record 5 of Set 6 | yuci
# Does not exist
# Processing Record 6 of Set 6 | hachinohe
# Does not exist
# Processing Record 7 of Set 6 | bolungarvik
# Does not exist
# Processing Record 8 of Set 6 | tuktoyaktuk
# Does not exist
# Processing Record 9 of Set 6 | rigaud
# Does not exist
# Processing Record 10 of Set 6 | tarakan
# Does not exist
# Processing Record 11 of Set 6 | rio gallegos
# Does not exist
# Processing Record 12 of Set 6 | gejiu
# Does not exist
# Processing Record 13 of Set 6 | arlit
# Does not exist
# Processing Record 14 of Set 6 | zhaotong
# Does not exist
# Processing Record 15 of Set 6 | iqaluit
# Does not exist
# Processing Record 16 of Set 6 | saskylakh
# Does not exist
# Processing Record 17 of Set 6 | barcelos
# Does not exist
# Processing Record 18 of Set 6 | borogontsy
# Does not exist
# Processing Record 19 of Set 6 | presidencia roque saenz pena
# Does not exist
# Processing Record 20 of Set 6 | zhanatas
# Does not exist
# Processing Record 21 of Set 6 | strzelce krajenskie
# Does not exist
# Processing Record 22 of Set 6 | eregli
# Does not exist
# Processing Record 23 of Set 6 | derzhavinsk
# Does not exist
# Processing Record 24 of Set 6 | half moon bay
# Does not exist
# Processing Record 25 of Set 6 | farafangana
# Does not exist
# Processing Record 26 of Set 6 | oussouye
# Does not exist
# Processing Record 27 of Set 6 | terrace bay
# Does not exist
# Processing Record 28 of Set 6 | juegang
# Does not exist
# Processing Record 29 of Set 6 | guarapari
# Does not exist
# Processing Record 30 of Set 6 | scarborough
# Does not exist
# Processing Record 31 of Set 6 | bridlington
# Does not exist
# Processing Record 32 of Set 6 | masuguru
# Does not exist
# Processing Record 33 of Set 6 | cove
# Does not exist
# Processing Record 34 of Set 6 | lyubech
# Does not exist
# Processing Record 35 of Set 6 | mount isa
# Does not exist
# Processing Record 36 of Set 6 | kirakira
# Does not exist
# Processing Record 37 of Set 6 | tezu
# Does not exist
# Processing Record 38 of Set 6 | kazalinsk
# Does not exist
# Processing Record 39 of Set 6 | belushya guba
# Does not exist
# Processing Record 40 of Set 6 | turan
# Does not exist
# Processing Record 41 of Set 6 | jacareacanga
# Does not exist
# Processing Record 42 of Set 6 | adamas
# Does not exist
# Processing Record 43 of Set 6 | bad kreuznach
# Does not exist
# Processing Record 44 of Set 6 | lompoc
# Does not exist
# Processing Record 45 of Set 6 | constitucion
# Does not exist
# Processing Record 46 of Set 6 | wajir
# Does not exist
# Processing Record 47 of Set 6 | lianzhou
# Does not exist
# Processing Record 48 of Set 6 | antsirabe
# Does not exist
# Processing Record 49 of Set 6 | kuopio
# Does not exist
# Processing Record 0 of Set 7 | along
# Does not exist
# Processing Record 1 of Set 7 | murray bridge
# Does not exist
# Processing Record 2 of Set 7 | sault sainte marie
# Does not exist
# Processing Record 3 of Set 7 | vaitape
# Does not exist
# Processing Record 4 of Set 7 | narsaq
# Does not exist
# Processing Record 5 of Set 7 | tiquicheo
# Does not exist
# Processing Record 6 of Set 7 | udachnyy
# Does not exist
# Processing Record 7 of Set 7 | egvekinot
# Does not exist
# Processing Record 8 of Set 7 | barranca
# Does not exist
# Processing Record 9 of Set 7 | yumen
# Does not exist
# Processing Record 10 of Set 7 | nishihara
# Does not exist
# Processing Record 11 of Set 7 | hovd
# Does not exist
# Processing Record 12 of Set 7 | ahipara
# Does not exist
# Processing Record 13 of Set 7 | kismayo
# Does not exist
# Processing Record 14 of Set 7 | miri
# Does not exist
# Processing Record 15 of Set 7 | kieta
# Does not exist
# Processing Record 16 of Set 7 | bicas
# Does not exist
# Processing Record 17 of Set 7 | te anau
# Does not exist
# Processing Record 18 of Set 7 | eugene
# Does not exist
# Processing Record 19 of Set 7 | abha
# Does not exist
# Processing Record 20 of Set 7 | tovste
# Does not exist
# Processing Record 21 of Set 7 | portland
# Does not exist
# Processing Record 22 of Set 7 | qui nhon
# Does not exist
# Processing Record 23 of Set 7 | knysna
# Does not exist
# Processing Record 24 of Set 7 | nguiu
# Does not exist
# Processing Record 25 of Set 7 | sept-iles
# Does not exist
# Processing Record 26 of Set 7 | scottsburgh
# Does not exist
# Processing Record 27 of Set 7 | axim
# Does not exist
# Processing Record 28 of Set 7 | san marco in lamis
# Does not exist
# Processing Record 29 of Set 7 | hwange
# Does not exist
# Processing Record 30 of Set 7 | sibul
# Does not exist
# Processing Record 31 of Set 7 | sala
# Does not exist
# Processing Record 32 of Set 7 | canutama
# Does not exist
# Processing Record 33 of Set 7 | krasnyy chikoy
# Does not exist
# Processing Record 34 of Set 7 | olavarria
# Does not exist
# Processing Record 35 of Set 7 | saint george
# Does not exist
# Processing Record 36 of Set 7 | kysyl-syr
# Does not exist
# Processing Record 37 of Set 7 | cairns
# Does not exist
# Processing Record 38 of Set 7 | balasinor
# Does not exist
# Processing Record 39 of Set 7 | los llanos de aridane
# Does not exist
# Processing Record 40 of Set 7 | dongsheng
# Does not exist
# Processing Record 41 of Set 7 | port blair
# Does not exist
# Processing Record 42 of Set 7 | bageshwar
# Does not exist
# Processing Record 43 of Set 7 | ankang
# Does not exist
# Processing Record 44 of Set 7 | shonguy
# Does not exist
# Processing Record 45 of Set 7 | puerto leguizamo
# Does not exist
# Processing Record 46 of Set 7 | cabo san lucas
# Does not exist
# Processing Record 47 of Set 7 | dera bugti
# Does not exist
# Processing Record 48 of Set 7 | vardo
# Does not exist
# Processing Record 49 of Set 7 | bargal
# Does not exist
# Processing Record 0 of Set 8 | mkushi
# Does not exist
# Processing Record 1 of Set 8 | khorinsk
# Does not exist
# Processing Record 2 of Set 8 | terney
# Does not exist
# Processing Record 3 of Set 8 | krutikha
# Does not exist
# Processing Record 4 of Set 8 | san quintin
# Does not exist
# Processing Record 5 of Set 8 | nouakchott
# Does not exist
# Processing Record 6 of Set 8 | jatiroto
# Does not exist
# Processing Record 7 of Set 8 | gat
# Does not exist
# Processing Record 8 of Set 8 | beboto
# Does not exist
# Processing Record 9 of Set 8 | clyde river
# Does not exist
# Processing Record 10 of Set 8 | herat
# Does not exist
# Processing Record 11 of Set 8 | saint-augustin
# Does not exist
# Processing Record 12 of Set 8 | norman wells
# Does not exist
# Processing Record 13 of Set 8 | namibe
# Does not exist
# Processing Record 14 of Set 8 | hambantota
# Does not exist
# Processing Record 15 of Set 8 | tokur
# Does not exist
# Processing Record 16 of Set 8 | juifang
# Does not exist
# Processing Record 17 of Set 8 | jati
# Does not exist
# Processing Record 18 of Set 8 | aquiraz
# Does not exist
# Processing Record 19 of Set 8 | yefremov
# Does not exist
# Processing Record 20 of Set 8 | lata
# Does not exist
# Processing Record 21 of Set 8 | daru
# Does not exist
# Processing Record 22 of Set 8 | lavrentiya
# Does not exist
# Processing Record 23 of Set 8 | coahuayana
# Does not exist
# Processing Record 24 of Set 8 | pangnirtung
# Does not exist
# Processing Record 25 of Set 8 | cururupu
# Does not exist
# Processing Record 26 of Set 8 | aflu
# Does not exist
# Processing Record 27 of Set 8 | marzuq
# Does not exist
# Processing Record 28 of Set 8 | atar
# Does not exist
# Processing Record 29 of Set 8 | lagoa
# Does not exist
# Processing Record 30 of Set 8 | grand-santi
# Does not exist
# Processing Record 31 of Set 8 | bontang
# Does not exist
# Processing Record 32 of Set 8 | pisco
# Does not exist
# Processing Record 33 of Set 8 | aurillac
# Does not exist
# Processing Record 34 of Set 8 | andros town
# Does not exist
# Processing Record 35 of Set 8 | quelimane
# Does not exist
# Processing Record 36 of Set 8 | talnakh
# Does not exist
# Processing Record 37 of Set 8 | honiara
# Does not exist
# Processing Record 38 of Set 8 | kurilsk
# Does not exist
# Processing Record 39 of Set 8 | ayia galini
# Does not exist
# Processing Record 40 of Set 8 | ambositra
# Does not exist
# Processing Record 41 of Set 8 | guerrero negro
# Does not exist
# Processing Record 42 of Set 8 | porto novo
# Does not exist
# Processing Record 43 of Set 8 | yar-sale
# Does not exist
# Processing Record 44 of Set 8 | augusto correa
# Does not exist
# Processing Record 45 of Set 8 | cidreira
# Does not exist
# Processing Record 46 of Set 8 | vostok
# Does not exist
# Processing Record 47 of Set 8 | bubaque
# Does not exist
# Processing Record 48 of Set 8 | laguna
# Does not exist
# Processing Record 49 of Set 8 | tucuman
# Does not exist
# Processing Record 0 of Set 9 | naze
# Does not exist
# Processing Record 1 of Set 9 | assiniboia
# Does not exist
# Processing Record 2 of Set 9 | merke
# Does not exist
# Processing Record 3 of Set 9 | visby
# Does not exist
# Processing Record 4 of Set 9 | forecariah
# Does not exist
# Processing Record 5 of Set 9 | gimli
# Does not exist
# Processing Record 6 of Set 9 | starosubkhangulovo
# Does not exist
# Processing Record 7 of Set 9 | fuerte olimpo
# Does not exist
# Processing Record 8 of Set 9 | sulangan
# Does not exist
# Processing Record 9 of Set 9 | kloulklubed
# Does not exist
# Processing Record 10 of Set 9 | tura
# Does not exist
# Processing Record 11 of Set 9 | bereda
# Does not exist
# Processing Record 12 of Set 9 | san cristobal
# Does not exist
# Processing Record 13 of Set 9 | rosendal
# Does not exist
# Processing Record 14 of Set 9 | farmington
# Does not exist
# Processing Record 15 of Set 9 | ust-tsilma
# Does not exist
# Processing Record 16 of Set 9 | bathsheba
# Does not exist
# Processing Record 17 of Set 9 | gulshat
# Does not exist
# Processing Record 18 of Set 9 | tabiauea
# Does not exist
# Processing Record 19 of Set 9 | awbari
# Does not exist
# Processing Record 20 of Set 9 | jiamusi
# Does not exist
# Processing Record 21 of Set 9 | muravlenko
# Does not exist
# Processing Record 22 of Set 9 | puerto escondido
# Does not exist
# Processing Record 23 of Set 9 | sampit
# Does not exist
# Processing Record 24 of Set 9 | talakan
# Does not exist
# Processing Record 25 of Set 9 | trairi
# Does not exist
# Processing Record 26 of Set 9 | sao jose da coroa grande
# Does not exist
# Processing Record 27 of Set 9 | cumaribo
# Does not exist
# Processing Record 28 of Set 9 | ayan
# Does not exist
# Processing Record 29 of Set 9 | kayes
# Does not exist
# Processing Record 30 of Set 9 | cilibia
# Does not exist
# Processing Record 31 of Set 9 | karratha
# Does not exist
# Processing Record 32 of Set 9 | port hardy
# Does not exist
# Processing Record 33 of Set 9 | west bay
# Does not exist
# Processing Record 34 of Set 9 | bafoulabe
# Does not exist
# Processing Record 35 of Set 9 | ngukurr
# Does not exist
# Processing Record 36 of Set 9 | starkville
# Does not exist
# Processing Record 37 of Set 9 | talara
# Does not exist
# Processing Record 38 of Set 9 | villa guerrero
# Does not exist
# Processing Record 39 of Set 9 | xingcheng
# Does not exist
# Processing Record 40 of Set 9 | kashi
# Does not exist
# Processing Record 41 of Set 9 | geraldton
# Does not exist
# Processing Record 42 of Set 9 | wau
# Does not exist
# Processing Record 43 of Set 9 | sao bernardo
# Does not exist
# Processing Record 44 of Set 9 | port lavaca
# Does not exist
# Processing Record 45 of Set 9 | roma
# Does not exist
# Processing Record 46 of Set 9 | vrangel
# Does not exist
# Processing Record 47 of Set 9 | tuatapere
# Does not exist
# Processing Record 48 of Set 9 | talcahuano
# Does not exist
# Processing Record 49 of Set 9 | kalangala
# Does not exist
# Processing Record 0 of Set 10 | coolum beach
# Does not exist
# Processing Record 1 of Set 10 | tonj
# Does not exist
# Processing Record 2 of Set 10 | launceston
# Does not exist
# Processing Record 3 of Set 10 | kailua
# Does not exist
# Processing Record 4 of Set 10 | kimbe
# Does not exist
# Processing Record 5 of Set 10 | tahoua
# Does not exist
# Processing Record 6 of Set 10 | mahina
# Does not exist
# Processing Record 7 of Set 10 | vestmannaeyjar
# Does not exist
# Processing Record 8 of Set 10 | lufilufi
# Does not exist
# Processing Record 9 of Set 10 | gladstone
# Does not exist
# Processing Record 10 of Set 10 | baker city
# Does not exist
# Processing Record 11 of Set 10 | grand gaube
# Does not exist
# Processing Record 12 of Set 10 | lengshuitan
# Does not exist
# Processing Record 13 of Set 10 | boueni
# Does not exist
# Processing Record 14 of Set 10 | torrelavega
# Does not exist
# Processing Record 15 of Set 10 | tiznit
# Does not exist
# Processing Record 16 of Set 10 | kalispell
# Does not exist
# Processing Record 17 of Set 10 | ambilobe
# Does not exist
# Processing Record 18 of Set 10 | imphal
# Does not exist
# Processing Record 19 of Set 10 | tautira
# Does not exist
# Processing Record 20 of Set 10 | preobrazheniye
# Does not exist
# Processing Record 21 of Set 10 | amahai
# Does not exist
# Processing Record 22 of Set 10 | samusu
# Does not exist
# Processing Record 23 of Set 10 | la ronge
# Does not exist
# Processing Record 24 of Set 10 | tabou
# Does not exist
# Processing Record 25 of Set 10 | peto
# Does not exist
# Processing Record 26 of Set 10 | magadan
# Does not exist
# Processing Record 27 of Set 10 | berestechko
# Does not exist
# Processing Record 28 of Set 10 | bang saphan
# Does not exist
# Processing Record 29 of Set 10 | maldonado
# Does not exist
# Processing Record 30 of Set 10 | bilma
# Does not exist
# Processing Record 31 of Set 10 | linjiang
# Does not exist
# Processing Record 32 of Set 10 | goundam
# Does not exist
# Processing Record 33 of Set 10 | ascension
# Does not exist
# Processing Record 34 of Set 10 | karaj
# Does not exist
# Processing Record 35 of Set 10 | tevaitoa
# Does not exist
# Processing Record 36 of Set 10 | waiuku
# Does not exist
# Processing Record 37 of Set 10 | bandar-e lengeh
# Does not exist
# Processing Record 38 of Set 10 | zadonsk
# Does not exist
# Processing Record 39 of Set 10 | garowe
# Does not exist
# Processing Record 40 of Set 10 | sambava
# Does not exist
# Processing Record 41 of Set 10 | mayumba
# Does not exist
# Processing Record 42 of Set 10 | walvis bay
# Does not exist
# Processing Record 43 of Set 10 | kaeo
# Does not exist
# Processing Record 44 of Set 10 | muros
# Does not exist
# Processing Record 45 of Set 10 | qingyuan
# Does not exist
# Processing Record 46 of Set 10 | olafsvik
# Does not exist
# Processing Record 47 of Set 10 | carroll
# Does not exist
# Processing Record 48 of Set 10 | kikwit
# Does not exist
# Processing Record 49 of Set 10 | rassvet
# Does not exist
# Processing Record 0 of Set 11 | aksarka
# Does not exist
# Processing Record 1 of Set 11 | gabrovo
# Does not exist
# Processing Record 2 of Set 11 | hamilton
# Does not exist
# Processing Record 3 of Set 11 | zambezi
# Does not exist
# Processing Record 4 of Set 11 | lolua
# Does not exist
# Processing Record 5 of Set 11 | berezovyy
# Does not exist
# Processing Record 6 of Set 11 | balykshi
# Does not exist
# Processing Record 7 of Set 11 | port hawkesbury
# Does not exist
# Processing Record 8 of Set 11 | caravelas
# Does not exist
# Processing Record 9 of Set 11 | plettenberg bay
# Does not exist
# Processing Record 10 of Set 11 | hirara
# Does not exist
# Processing Record 11 of Set 11 | sinnamary
# Does not exist
# Processing Record 12 of Set 11 | kyra
# Does not exist
# Processing Record 13 of Set 11 | ippy
# Does not exist
# Processing Record 14 of Set 11 | torres
# Does not exist
# Processing Record 15 of Set 11 | ahuimanu
# Does not exist
# Processing Record 16 of Set 11 | nyurba
# Does not exist
# Processing Record 17 of Set 11 | lebyazhye
# Does not exist
# Processing Record 18 of Set 11 | mehamn
# Does not exist
# Processing Record 19 of Set 11 | pacific grove
# Does not exist
# Processing Record 20 of Set 11 | margate
# Does not exist
# Processing Record 21 of Set 11 | kapuskasing
# Does not exist
# Processing Record 22 of Set 11 | pakokku
# Does not exist
# Processing Record 23 of Set 11 | ayagoz
# Does not exist
# Processing Record 24 of Set 11 | great falls
# Does not exist
# Processing Record 25 of Set 11 | pihani
# Does not exist
# Processing Record 26 of Set 11 | rabo de peixe
# Does not exist
# Processing Record 27 of Set 11 | labuhan
# Does not exist
# Processing Record 28 of Set 11 | tsabong
# Does not exist
# Processing Record 29 of Set 11 | richards bay
# Does not exist
# Processing Record 30 of Set 11 | englewood
# Does not exist
# Processing Record 31 of Set 11 | mangrol
# Does not exist
# Processing Record 32 of Set 11 | shelbyville
# Does not exist
# Processing Record 33 of Set 11 | milingimbi
# Does not exist
# Processing Record 34 of Set 11 | stevens point
# Does not exist
# Processing Record 35 of Set 11 | alenquer
# Does not exist
# Processing Record 36 of Set 11 | moussoro
# Does not exist
# Processing Record 37 of Set 11 | avera
# Does not exist
# Processing Record 38 of Set 11 | cruzeiro do oeste
# Does not exist
# Processing Record 39 of Set 11 | touros
# Does not exist
# Processing Record 40 of Set 11 | savannakhet
# Does not exist
# Processing Record 41 of Set 11 | beloha
# Does not exist
# Processing Record 42 of Set 11 | cerritos
# Does not exist
# Processing Record 43 of Set 11 | taoudenni
# Does not exist
# Processing Record 44 of Set 11 | ulundi
# Does not exist
# Processing Record 45 of Set 11 | umzimvubu
# Does not exist
# Processing Record 46 of Set 11 | son la
# Does not exist
# Processing Record 47 of Set 11 | whitehorse
# Does not exist
# Processing Record 48 of Set 11 | saint-ambroise
# Does not exist
# Processing Record 49 of Set 11 | evanston
# Does not exist
# Processing Record 0 of Set 12 | windsor
# Does not exist
# Processing Record 1 of Set 12 | druzhba
# Does not exist
# Processing Record 2 of Set 12 | raudeberg
# Does not exist
# Processing Record 3 of Set 12 | cheuskiny
# Does not exist
# Processing Record 4 of Set 12 | saint-pierre
# Does not exist
# Processing Record 5 of Set 12 | cap malheureux
# Does not exist
# Processing Record 6 of Set 12 | babanusah
# Does not exist
# Processing Record 7 of Set 12 | hofn
# Does not exist
# Processing Record 8 of Set 12 | ixtapa
# Does not exist
# Processing Record 9 of Set 12 | sarankhola
# Does not exist
# Processing Record 10 of Set 12 | bolshaya dzhalga
# Does not exist
# Processing Record 11 of Set 12 | klaksvik
# Does not exist
# Processing Record 12 of Set 12 | camacha
# Does not exist
# Processing Record 13 of Set 12 | bunia
# Does not exist
# Processing Record 14 of Set 12 | pavlohrad
# Does not exist
# Processing Record 15 of Set 12 | dolores
# Does not exist
# Processing Record 16 of Set 12 | coquimbo
# Does not exist
# Processing Record 17 of Set 12 | show low
# Does not exist
# Processing Record 18 of Set 12 | tabas
# Does not exist
# Processing Record 19 of Set 12 | grodkow
# Does not exist
# Processing Record 20 of Set 12 | longyearbyen
# Does not exist
# Processing Record 21 of Set 12 | severobaykalsk
# Does not exist
# Processing Record 22 of Set 12 | vilyuysk
# Does not exist
# Processing Record 23 of Set 12 | oktyabrskiy
# Does not exist
# Processing Record 24 of Set 12 | jutai
# Does not exist
# Processing Record 25 of Set 12 | broome
# Does not exist
# Processing Record 26 of Set 12 | louisbourg
# Does not exist
# Processing Record 27 of Set 12 | natal
# Does not exist
# Processing Record 28 of Set 12 | makung
# Does not exist
# Processing Record 29 of Set 12 | coromandel
# Does not exist
# Processing Record 30 of Set 12 | peniche
# Does not exist
# Processing Record 31 of Set 12 | siverek
# Does not exist
# Processing Record 32 of Set 12 | bay roberts
# Does not exist
# Processing Record 33 of Set 12 | macon
# Does not exist
# Processing Record 34 of Set 12 | glubokiy
# Does not exist
# Processing Record 35 of Set 12 | storsteinnes
# Does not exist
# Processing Record 36 of Set 12 | parrita
# Does not exist
# Processing Record 37 of Set 12 | bonnyville
# Does not exist
# Processing Record 38 of Set 12 | sogdiondon
# Does not exist
# Processing Record 39 of Set 12 | sao joao da barra
# Does not exist
# Processing Record 40 of Set 12 | chimbote
# Does not exist
# Processing Record 41 of Set 12 | abu samrah
# Does not exist
# Processing Record 42 of Set 12 | damaturu
# Does not exist
# Processing Record 43 of Set 12 | ola
# Does not exist
# Processing Record 44 of Set 12 | abu kamal
# Does not exist
# Processing Record 45 of Set 12 | sangar
# Does not exist
# Processing Record 46 of Set 12 | senador jose porfirio
# Does not exist
# Processing Record 47 of Set 12 | umm lajj
# Does not exist
# Processing Record 48 of Set 12 | pueblo nuevo
# Does not exist
# Processing Record 49 of Set 12 | antsohihy
# Does not exist
# Processing Record 0 of Set 13 | sale
# Does not exist
# Processing Record 1 of Set 13 | ascoli piceno
# Does not exist
# Processing Record 2 of Set 13 | el real de santa maria
# Does not exist
# Processing Record 3 of Set 13 | el alto
# Does not exist
# Processing Record 4 of Set 13 | vaitupu
# Does not exist
# Processing Record 5 of Set 13 | aykhal
# Does not exist
# Processing Record 6 of Set 13 | sarnia
# Does not exist
# Processing Record 7 of Set 13 | djibo
# Does not exist
# Processing Record 8 of Set 13 | ridgecrest
# Does not exist
# Processing Record 9 of Set 13 | bagdarin
# Does not exist
# Processing Record 10 of Set 13 | winchester
# Does not exist
# Processing Record 11 of Set 13 | mubi
# Does not exist
# Processing Record 12 of Set 13 | banda aceh
# Does not exist
# -----------------------------
# Search Complete
# -----------------------------

# %%
city_weather
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}

# %%
print(clc_weather)
# Out:
# {'coord': {'lon': -77.29, 'lat': 38.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.18, 'feels_like': 64.44, 'temp_min': 62.01, 'temp_max': 66.2, 'pressure': 1015, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 260}, 'clouds': {'all': 1}, 'dt': 1600907080, 'sys': {'type': 1, 'id': 5134, 'country': 'US', 'sunrise': 1600858690, 'sunset': 1600902272}, 'timezone': -14400, 'id': 4780087, 'name': 'Potomac Mills', 'cod': 200}
